# %% [markdown]
# # Assignment 1
# ### CSC 478
# #### Kristen Groom
# #### 4/11/18

# %% [markdown]
# #### 1) Explore the general characteristics of the data as a whole: examine the means, standard deviations, and other statistics associated with the numerical attributes; show the distributions of values associated with categorical attributes; etc.

# %%
# import needed libraries for assignment:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read in the data as a pandas DataFrame:
bdtable = pd.read_csv("bank_data.csv")
bdtable
# Out:
#           id  age    income  children  gender      region married  car  \
# 0    ID12101   48  17546.00         1  FEMALE  INNER_CITY      NO   NO
# 1    ID12102   40  30085.10         3    MALE        TOWN     YES  YES
# 2    ID12103   51  16575.40         0  FEMALE  INNER_CITY     YES  YES
# 3    ID12104   23  20375.40         3  FEMALE        TOWN     YES   NO
# 4    ID12105   57  50576.30         0  FEMALE       RURAL     YES   NO
# 5    ID12106   57  37869.60         2  FEMALE        TOWN     YES   NO
# 6    ID12107   22   8877.07         0    MALE       RURAL      NO   NO
# 7    ID12108   58  24946.60         0    MALE        TOWN     YES  YES
# 8    ID12109   37  25304.30         2  FEMALE    SUBURBAN     YES  YES
# 9    ID12110   54  24212.10         2    MALE        TOWN     YES  YES
# 10   ID12111   66  59803.90         0  FEMALE        TOWN     YES   NO
# 11   ID12112   52  26658.80         0  FEMALE  INNER_CITY      NO  YES
# ...

# %%
# size of the data:
bdtable.shape
# Out:
# (600, 12)

# %%
# viewing basic descriptions of the data:
bdtable.dtypes
# Out:
# id               object
# age               int64
# income          float64
# children          int64
# gender           object
# region           object
# married          object
# car              object
# savings_acct     object
# current_acct     object
# mortgage         object
# pep              object
# dtype: object

# %% [markdown]
# #### General characteristics of numerical data:

# %%
# Mean values for age, income, children
print "Mean age of bank customers: ", bdtable['age'].mean()
# Out:
# Mean age of bank customers:  42.395

# %%
print "Mean income of bank customers: $", round(bdtable['income'].mean(), 2)
# Out:
# Mean income of bank customers: $ 27524.03

# %%
print "Mean number of bank customer children: ", round(bdtable['children'].mean())
# Out:
# Mean number of bank customer children:  1.0

# %%
# descriptive statistics for numerical attributes (rounded by 3 decimals for ease of reading):
bdtable[['age', 'income', 'children']].describe().round(3)
# Out:
#            age     income  children
# count  600.000    600.000   600.000
# mean    42.395  27524.031     1.012
# std     14.425  12899.468     1.057
# min     18.000   5014.210     0.000
# 25%     30.000  17264.500     0.000
# 50%     42.000  24925.300     1.000
# 75%     55.250  36172.675     2.000
# max     67.000  63130.100     3.000

# %%
# basic correlation analysis of numerical values:
bdtable[['age', 'income', 'children']].corr()
# Out:
#                age    income  children
# age       1.000000  0.752726  0.023572
# income    0.752726  1.000000  0.036761
# children  0.023572  0.036761  1.000000

# %% [markdown]
# We see from our numerical data above that the average age of our bank customers is approximately 42, with customers as young as 18 and up to 67 years of age.  Average income for our bank is approximately $28,000, and from our correlation analysis, we see that there is a positive correlation between age and income.  Average children of bank customers is 1, with our customers having up to 3 children.

# %%
# we can see when we try to perform descriptive statistics on all variables, we will get some missing values
# for the categorical attributes, and for some of the numerical values:
bdtable.describe(include="all")
# Out:
#              id         age        income    children gender      region  \
# count       600  600.000000    600.000000  600.000000    600         600
# unique      600         NaN           NaN         NaN      2           4
# top     ID12208         NaN           NaN         NaN   MALE  INNER_CITY
# freq          1         NaN           NaN         NaN    300         269
# mean        NaN   42.395000  27524.031217    1.011667    NaN         NaN
# std         NaN   14.424947  12899.468246    1.056752    NaN         NaN
# min         NaN   18.000000   5014.210000    0.000000    NaN         NaN
# 25%         NaN   30.000000  17264.500000    0.000000    NaN         NaN
# 50%         NaN   42.000000  24925.300000    1.000000    NaN         NaN
# 75%         NaN   55.250000  36172.675000    2.000000    NaN         NaN
# max         NaN   67.000000  63130.100000    3.000000    NaN         NaN
#
#        married  car savings_acct current_acct mortgage  pep
# ...

# %% [markdown]
# #### Distributions of categorical attributes:

# %%
# viewing regions of our customers:
bdtable['region'].value_counts()
# Out:
# INNER_CITY    269
# TOWN          173
# RURAL          96
# SUBURBAN       62
# Name: region, dtype: int64

# %%
# looking at how many of our customers are married
bdtable['married'].value_counts()
# Out:
# YES    396
# NO     204
# Name: married, dtype: int64

# %%
# how many own a car:
bdtable['car'].value_counts()
# Out:
# NO     304
# YES    296
# Name: car, dtype: int64

# %%
# male/female distribution
bdtable['gender'].value_counts()
# Out:
# MALE      300
# FEMALE    300
# Name: gender, dtype: int64

# %%
# have savings accounts 
bdtable['savings_acct'].value_counts()
# Out:
# YES    414
# NO     186
# Name: savings_acct, dtype: int64

# %%
# with active accounts
bdtable['current_acct'].value_counts()
# Out:
# YES    455
# NO     145
# Name: current_acct, dtype: int64

# %%
# customers with mortgage
bdtable['mortgage'].value_counts()
# Out:
# NO     391
# YES    209
# Name: mortgage, dtype: int64

# %%
# customers who have purchased a pep
bdtable['pep'].value_counts()
# Out:
# NO     326
# YES    274
# Name: pep, dtype: int64

# %% [markdown]
# #### 2) Suppose that the hypothetical bank is particularly interested in customers who buy the PEP (Personal Equity Plan) product. Compare and contrast the subsets of customers who buy and don't buy the PEP. Compute summaries (as in part 1) of the selected data with respect to all other attributes. Can you observe any significant differences between these segments of customers? Discuss your observations.

# %%
# describing pep purchases with all other vars:
bdtable.groupby("pep").describe(include='object').T
# Out:
# pep                          NO         YES
# car          count          326         274
#              unique           2           2
#              top             NO         YES
#              freq           168         138
# current_acct count          326         274
#              unique           2           2
#              top            YES         YES
#              freq           244         211
# gender       count          326         274
#              unique           2           2
#              top         FEMALE        MALE
#              freq           170         144
# id           count          326         274
#              unique         326         274
#              top        ID12208     ID12367
#              freq             1           1
# married      count          326         274
#              unique           2           2
#              top            YES         YES
#              freq           242         154
# ...

# %%
# viewing pep in relation to income:
bdtable.groupby("pep").describe(include=['int64', 'float64']).T
# Out:
# pep                       NO           YES
# age      count    326.000000    274.000000
#          mean      40.098160     45.127737
#          std       14.123506     14.327991
#          min       18.000000     18.000000
#          25%       27.000000     34.000000
#          50%       40.000000     45.000000
#          75%       51.000000     58.000000
#          max       67.000000     67.000000
# children count    326.000000    274.000000
#          mean       1.067485      0.945255
#          std        1.195524      0.860571
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
#          50%        0.000000      1.000000
#          75%        2.000000      1.000000
#          max        3.000000      3.000000
# income   count    326.000000    274.000000
#          mean   24900.953374  30644.919453
#          std    11661.123422  13609.613043
#          min     5014.210000   7756.360000
#          25%    15366.475000  19639.475000
# ...

# %%
#not sure why is isn't recognizing income above??
# look at descriptive statistics for customers who purchased pep vs those who did not:
purchased_pep = bdtable[bdtable.pep=='YES']

print "Customers who purchased a PEP:\n", purchased_pep.describe(include='all').round(4)
print("="*70)
print "All Customers:\n", bdtable.describe(include='all').round(4)
# Out:
# Customers who purchased a PEP:
#              id       age      income  children gender      region married  \
# count       274  274.0000    274.0000  274.0000    274         274     274
# unique      274       NaN         NaN       NaN      2           4       2
# top     ID12367       NaN         NaN       NaN   MALE  INNER_CITY     YES
# freq          1       NaN         NaN       NaN    144         123     154
# mean        NaN   45.1277  30644.9195    0.9453    NaN         NaN     NaN
# std         NaN   14.3280  13609.6130    0.8606    NaN         NaN     NaN
# min         NaN   18.0000   7756.3600    0.0000    NaN         NaN     NaN
# 25%         NaN   34.0000  19639.4750    0.0000    NaN         NaN     NaN
# 50%         NaN   45.0000  28080.0500    1.0000    NaN         NaN     NaN
# 75%         NaN   58.0000  38458.3500    1.0000    NaN         NaN     NaN
# max         NaN   67.0000  63130.1000    3.0000    NaN         NaN     NaN
#
# ...

# %%
# looking at a few of the variables that aren't very clear from the above findings:
# looking at pep and region:

bdtable.groupby(["region","pep"])["pep"].count()
# Out:
# region      pep
# INNER_CITY  NO     146
#             YES    123
# RURAL       NO      50
#             YES     46
# SUBURBAN    NO      28
#             YES     34
# TOWN        NO     102
#             YES     71
# Name: pep, dtype: int64

# %%
bdtable.groupby(["gender","pep"])["pep"].count()
# Out:
# gender  pep
# FEMALE  NO     170
#         YES    130
# MALE    NO     156
#         YES    144
# Name: pep, dtype: int64

# %%
bdtable.groupby(["married","pep"])["pep"].count()
# Out:
# married  pep
# NO       NO      84
#          YES    120
# YES      NO     242
#          YES    154
# Name: pep, dtype: int64

# %% [markdown]
# Some interesting findings:
#
# We can see that the average income for those who purchased pep's is slightly higher.  75% of customers who puchased pep's have less children than 75% of all customers.  Slightly more suburban customers perchased peps, as did slightly more males than females. We see that more people who purchased pep's were married than were not married.  Also, we see that those who purchased pep's are on average a few years older than those who did not purchase peps.

# %% [markdown]
# #### 3 ) Use z-score normalization to standardize the values of the income attribute. [Do not change the original income attribute in the table.]

# %%
# only using the 'income' attribute, create new variables so as to not change values in original data

bd_income = bdtable['income']
bd_std = (bd_income - bd_income.mean())/bd_income.std()
bd_std
# Out:
# 0     -0.773523
# 1      0.198541
# 2     -0.848766
# 3     -0.554180
# 4      1.787071
# 5      0.802015
# 6     -1.445560
# 7     -0.199809
# 8     -0.172079
# 9     -0.256749
# 10     2.502419
# 11    -0.067075
# 12    -0.913854
# 13     2.145877
# 14    -0.624013
# 15    -0.401717
# 16    -0.759274
# 17     1.045932
# 18    -0.047663
# 19    -0.387708
# 20     2.353327
# 21    -0.854821
# 22     0.846746
# 23    -0.929126
# 24    -1.153825
# 25     1.047328
# 26    -0.520512
# 27    -0.574445
# 28     0.142259
# 29    -0.252253
#          ...
# 570    0.476102
# 571    0.669963
# 572    0.014642
# 573   -0.397174
# 574    0.073326
# 575    0.229774
# 576   -0.648378
# 577    1.381334
# 578   -1.645790
# 579   -0.185770
# 580    1.888083
# 581   -1.153469
# 582   -0.429446
# 583    0.121638
# 584   -0.309752
# 585   -1.395958
# 586   -0.710039
# 587    0.290692
# 588    1.717092
# 589   -1.155135
# 590   -0.287255
# 591    0.306204
# 592   -0.562506
# 593    1.852244
# ...

# %% [markdown]
# #### 4) Discretize the age attribute into 3 categories (corresponding to "young", "mid-age", and "old"). [Do not change the original age attribute in the table.]

# %%
inc_bins = pd.qcut(bdtable.income, [0, .33, .66, 1], labels=['low', 'mid', 'high'])
inc_bins
# Out:
# 0       low
# 1       mid
# 2       low
# 3       mid
# 4      high
# 5      high
# 6       low
# 7       mid
# 8       mid
# 9       mid
# 10     high
# 11      mid
# 12      low
# 13     high
# 14      low
# 15      mid
# 16      low
# 17     high
# 18      mid
# 19      mid
# 20     high
# 21      low
# 22     high
# 23      low
# 24      low
# 25     high
# 26      mid
# 27      mid
# 28      mid
# 29      mid
#        ...
# 570    high
# 571    high
# 572     mid
# 573     mid
# 574     mid
# 575     mid
# 576     low
# 577    high
# 578     low
# 579     mid
# 580    high
# 581     low
# 582     mid
# 583     mid
# 584     mid
# 585     low
# 586     low
# 587    high
# 588    high
# 589     low
# 590     mid
# 591    high
# 592     mid
# 593    high
# 594    high
# 595    high
# 596     low
# 597     low
# 598     low
# 599     mid
# Name: income, Length: 600, dtype: category
# Categories (3, object): [low < mid < high]

# %% [markdown]
# #### 5) Use Min-Max Normalization to transform the values of all numeric attributes  (income, age, children) in the original table (before the transforamtions in parts 3 and 4 above) onto the range 0.0-1.0.

# %%
# viewing the table before min-max normalization:
bdtable.head(10)
# Out:
#         id  age    income  children  gender      region married  car  \
# 0  ID12101   48  17546.00         1  FEMALE  INNER_CITY      NO   NO
# 1  ID12102   40  30085.10         3    MALE        TOWN     YES  YES
# 2  ID12103   51  16575.40         0  FEMALE  INNER_CITY     YES  YES
# 3  ID12104   23  20375.40         3  FEMALE        TOWN     YES   NO
# 4  ID12105   57  50576.30         0  FEMALE       RURAL     YES   NO
# 5  ID12106   57  37869.60         2  FEMALE        TOWN     YES   NO
# 6  ID12107   22   8877.07         0    MALE       RURAL      NO   NO
# 7  ID12108   58  24946.60         0    MALE        TOWN     YES  YES
# 8  ID12109   37  25304.30         2  FEMALE    SUBURBAN     YES  YES
# 9  ID12110   54  24212.10         2    MALE        TOWN     YES  YES
#
#   savings_acct current_acct mortgage  pep
# 0           NO           NO       NO  YES
# 1           NO          YES      YES   NO
# 2          YES          YES       NO   NO
# ...

# %%
# performing min max normalization on only numerical attributes
bd_norm = bdtable.copy() # making a copy so it doesn't overwrite

minMax = lambda x: (x - x.min()) / (x.max() - x.min())
bd_norm[['age', 'income', 'children']] = bd_norm[['age','income','children']].apply(minMax)
bd_norm.head(10)
# Out:
#         id       age    income  children  gender      region married  car  \
# 0  ID12101  0.612245  0.215634  0.333333  FEMALE  INNER_CITY      NO   NO
# 1  ID12102  0.448980  0.431395  1.000000    MALE        TOWN     YES  YES
# 2  ID12103  0.673469  0.198933  0.000000  FEMALE  INNER_CITY     YES  YES
# 3  ID12104  0.102041  0.264320  1.000000  FEMALE        TOWN     YES   NO
# 4  ID12105  0.795918  0.783987  0.000000  FEMALE       RURAL     YES   NO
# 5  ID12106  0.795918  0.565343  0.666667  FEMALE        TOWN     YES   NO
# 6  ID12107  0.081633  0.066468  0.000000    MALE       RURAL      NO   NO
# 7  ID12108  0.816327  0.342977  0.000000    MALE        TOWN     YES  YES
# 8  ID12109  0.387755  0.349132  0.666667  FEMALE    SUBURBAN     YES  YES
# 9  ID12110  0.734694  0.330338  0.666667    MALE        TOWN     YES  YES
#
#   savings_acct current_acct mortgage  pep
# 0           NO           NO       NO  YES
# 1           NO          YES      YES   NO
# ...

# %% [markdown]
# #### 6) Convert the table (after normalization in part 5) into the standard spreadsheet format. Note that this requires converting each categorical attribute into multiple binary ("dummy") attributes (one for each values of the categorical attribute) and assigning binary values corresponding to the presence or not presence of the attribute value in the original record). The numeric attributes should remain unchanged. Save this new table into a file called bank_numeric.csv and submit it along with your assignment. [Hint: you might consider using the get_dummies for Pandas data frames.]

# %%
# not sure how to get rid of id's as a column for get_dummies - worked on this for a while, ugh
# i'll drop the ids for this part to make the next part easier...
bd_norm_id = bd_norm['id']
bd_norm_id.head(10)
# Out:
# 0    ID12101
# 1    ID12102
# 2    ID12103
# 3    ID12104
# 4    ID12105
# 5    ID12106
# 6    ID12107
# 7    ID12108
# 8    ID12109
# 9    ID12110
# Name: id, dtype: object

# %%
bd_norm_no_id = bd_norm.drop('id', axis=1)
bd_norm_no_id.head(10)
# Out:
#         age    income  children  gender      region married  car savings_acct  \
# 0  0.612245  0.215634  0.333333  FEMALE  INNER_CITY      NO   NO           NO
# 1  0.448980  0.431395  1.000000    MALE        TOWN     YES  YES           NO
# 2  0.673469  0.198933  0.000000  FEMALE  INNER_CITY     YES  YES          YES
# 3  0.102041  0.264320  1.000000  FEMALE        TOWN     YES   NO           NO
# 4  0.795918  0.783987  0.000000  FEMALE       RURAL     YES   NO          YES
# 5  0.795918  0.565343  0.666667  FEMALE        TOWN     YES   NO          YES
# 6  0.081633  0.066468  0.000000    MALE       RURAL      NO   NO           NO
# 7  0.816327  0.342977  0.000000    MALE        TOWN     YES  YES          YES
# 8  0.387755  0.349132  0.666667  FEMALE    SUBURBAN     YES  YES           NO
# 9  0.734694  0.330338  0.666667    MALE        TOWN     YES  YES          YES
#
#   current_acct mortgage  pep
# 0           NO       NO  YES
# 1          YES      YES   NO
# ...

# %%
bd_norm_dummies = pd.get_dummies(bd_norm_no_id)
bd_norm_dummies.head(10)
# Out:
#         age    income  children  gender_FEMALE  gender_MALE  \
# 0  0.612245  0.215634  0.333333              1            0
# 1  0.448980  0.431395  1.000000              0            1
# 2  0.673469  0.198933  0.000000              1            0
# 3  0.102041  0.264320  1.000000              1            0
# 4  0.795918  0.783987  0.000000              1            0
# 5  0.795918  0.565343  0.666667              1            0
# 6  0.081633  0.066468  0.000000              0            1
# 7  0.816327  0.342977  0.000000              0            1
# 8  0.387755  0.349132  0.666667              1            0
# 9  0.734694  0.330338  0.666667              0            1
#
#    region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN  married_NO  \
# 0                  1             0                0            0           1
# 1                  0             0                0            1           0
# ...

# %%
# now add back id to bd_norm 
bd_norm_dummies.insert(0, 'id', bd_norm_id)

# %%
bd_norm_dummies.head(10)
# Out:
#         id       age    income  children  gender_FEMALE  gender_MALE  \
# 0  ID12101  0.612245  0.215634  0.333333              1            0
# 1  ID12102  0.448980  0.431395  1.000000              0            1
# 2  ID12103  0.673469  0.198933  0.000000              1            0
# 3  ID12104  0.102041  0.264320  1.000000              1            0
# 4  ID12105  0.795918  0.783987  0.000000              1            0
# 5  ID12106  0.795918  0.565343  0.666667              1            0
# 6  ID12107  0.081633  0.066468  0.000000              0            1
# 7  ID12108  0.816327  0.342977  0.000000              0            1
# 8  ID12109  0.387755  0.349132  0.666667              1            0
# 9  ID12110  0.734694  0.330338  0.666667              0            1
#
#    region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN   ...     \
# 0                  1             0                0            0   ...
# ...

# %%
# save file to new csv file
bd_norm_dummies.to_csv("bank_numeric.csv", float_format="%1.2f") # formatted to only have 2 decimal points

# %%
# read in the data as a pandas DataFrame:
newbdtable = pd.read_csv("bank_numeric.csv", index_col=0)
newbdtable.head(10)
# Out:
#         id   age  income  children  gender_FEMALE  gender_MALE  \
# 0  ID12101  0.61    0.22      0.33              1            0
# 1  ID12102  0.45    0.43      1.00              0            1
# 2  ID12103  0.67    0.20      0.00              1            0
# 3  ID12104  0.10    0.26      1.00              1            0
# 4  ID12105  0.80    0.78      0.00              1            0
# 5  ID12106  0.80    0.57      0.67              1            0
# 6  ID12107  0.08    0.07      0.00              0            1
# 7  ID12108  0.82    0.34      0.00              0            1
# 8  ID12109  0.39    0.35      0.67              1            0
# 9  ID12110  0.73    0.33      0.67              0            1
#
#    region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN   ...     \
# 0                  1             0                0            0   ...
# 1                  0             0                0            1   ...
# ...

# %% [markdown]
# #### 7) Using the standardized data set (of the previous part), perform basic correlation analysis among the attributes. Discuss your results by indicating any significant positive or negative correlations among pairs of attributes. You need to construct a complete Correlation Matrix. Be sure to first remove the Customer ID column before creating the correlation matrix. [Hint: you can create the correlation matrix by using the corr() function in Pandas or corrcoef function in NumPy].

# %%
# correlation analysis:

newbdtable.corr()

# gives a correlation matrix where 1's are correlating vars with themselves - then you can see the other vars
# and how they correlate with one another - diagonal are 1's
# Out:
#                         age    income  children  gender_FEMALE  gender_MALE  \
# age                1.000000  0.752720  0.022995       0.089784    -0.089784
# income             0.752720  1.000000  0.035464       0.023136    -0.023136
# children           0.022995  0.035464  1.000000       0.014130    -0.014130
# gender_FEMALE      0.089784  0.023136  0.014130       1.000000    -1.000000
# gender_MALE       -0.089784 -0.023136 -0.014130      -1.000000     1.000000
# region_INNER_CITY -0.025809 -0.047333 -0.051326      -0.023459     0.023459
# region_RURAL       0.018594  0.086247  0.089942      -0.009092     0.009092
# region_SUBURBAN    0.031061  0.029056 -0.013778      -0.010951     0.010951
# region_TOWN       -0.007585 -0.037359 -0.007183       0.040472    -0.040472
# married_NO        -0.010394  0.007941  0.048762       0.021110    -0.021110
# married_YES        0.010394 -0.007941 -0.048762      -0.021110     0.021110
# ...

# %% [markdown]
# We can see a strong positive correlation between age and income.  We see a small positive correlation between having a savings account and income levels as well as income and having purchased a pep. Mostly, I am see very small to insignificant correlations among the variables with the most notable being age and income

# %% [markdown]
# #### 8) Using Matplotlib library and/or ploting capabilties of Pandas, create a scatter plot of the (non-normalized) Income attribute relative to Age. Be sure that your plot contains appropriate labels for the axes. Do these variables seem correlated?

# %%
# using pyplot to create a scatterplot 
bdtable.plot(x="income", y="age", kind="scatter")

# %% [markdown]
# We definitely see a very strong correlation between age and income

# %% [markdown]
# #### 9) Create histograms for (non-normalized) Income (using 9 bins) and Age (using 15 bins).

# %%
# histogram for income
bdtable['income'].plot(kind='hist', bins=9, grid=True)

# %%
bdtable['age'].plot(kind='hist', bins=15, grid=True)

# %% [markdown]
# #### 10) Using a bargraph, plot the distribution of the values of the region attribute.

# %%
bdtable["region"].value_counts().plot(kind='bar')

# %% [markdown]
# #### 11) Perform a cross-tabulation of the region attribute with the pep attribute. This requires the aggregation of the occurrences of each pep value (yes or no) separately for each value of the region attribute. Show the results as a 4 by 2 (region x pep) table with entries representing the counts. [Hint: you can either use Numpy or use aggregations fucntions in Pandas such as groupby() and  cross-tab().] Then, either using Matplotlib directly or the plot() function in Pandas create a bar chart graph to visualize of the relationships between these sets of variables.

# %%
# cross-tabulation of region and pep using pd.crosstab

x=pd.crosstab(bdtable['region'], bdtable['pep']) # can add margins=True if we want to see the totals as well
x.head(10)
# Out:
# pep          NO  YES
# region
# INNER_CITY  146  123
# RURAL        50   46
# SUBURBAN     28   34
# TOWN        102   71

# %%
# plot a bar chart visualizing region and pep

plt.show(x.plot(kind="bar"))
